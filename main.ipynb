# %% [markdown]
# #**Data Preparation**

# %%
# Data Preparation for Colab
# Packages
import json
from pathlib import Path
import shutil
import random
# !pip install ultralytics
# Out:
# Requirement already satisfied: ultralytics in /usr/local/lib/python3.12/dist-packages (8.3.235)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (4.12.0.88)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.32.4)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.16.3)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.9.0+cu126)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (0.24.0+cu126)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: polars>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.31.0)
# Requirement already satisfied: ultralytics-thop>=2.0.18 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.0.18)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2025.11.12)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.6)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.3)

# %%
# ============================================================
# SETUP: Download Kaggle Dataset
# ============================================================
import kagglehub
avishkar2027_tree_canopy_dataset_dl_path = kagglehub.dataset_download('avishkar2027/tree-canopy-dataset-dl')
print('Data source import complete.')
# Out:
# Using Colab cache for faster access to the 'tree-canopy-dataset-dl' dataset.
# Data source import complete.

# %%
import os

# List all files and directories in the path
contents = os.listdir(avishkar2027_tree_canopy_dataset_dl_path)

print(f"Contents of {avishkar2027_tree_canopy_dataset_dl_path}:")
for item in contents:
    print(item)
# Out:
# Contents of /kaggle/input/tree-canopy-dataset-dl:
# train_images
# evaluation_images
# train_annotations.json
# sample_answer.json

# %%
# ============================================================
# PARAMETERS
# ============================================================
# Set up paths relative to the downloaded dataset
DATASET_PATH = Path(avishkar2027_tree_canopy_dataset_dl_path)
DATA_ROOT = Path('/content/treecanopy_data_DL')  # Main data directory

# Create root directory
DATA_ROOT.mkdir(parents=True, exist_ok=True)

print(f"Dataset downloaded to: {DATASET_PATH}")
print(f"Working directory: {DATA_ROOT}")
# Out:
# Dataset downloaded to: /kaggle/input/tree-canopy-dataset-dl
# Working directory: /content/treecanopy_data_DL

# %%
# ============================================================
# JSON CONVERSION: Solafune JSON to COCO Format
# ============================================================
print("\n Converting Solafune JSON to COCO format...")

# Input and output paths (adjust based on your Kaggle dataset structure)
input_path = DATASET_PATH / 'train_annotations.json'  # Adjust if needed
output_path = DATA_ROOT / 'processed/JSONs/train_annotations_coco.json'

# Read train annotations data
with open(input_path) as f:
    train_annotations = json.load(f)

# Initialize COCO data structure
coco_data = {
    "images": [],
    "annotations": [],
    "categories": [
        {"id": 1, "name": "individual_tree", "supercategory": "tree"},
        {"id": 2, "name": "group_of_trees", "supercategory": "tree"},
    ]
}

# Category mapping
category_map = {
    "individual_tree": 1,
    "group_of_trees": 2
}

# Initialize annotation and image ID counters
annotation_id = 1
image_id = 1

# For each image...
for image in train_annotations["images"]:

    # Add image metadata
    coco_data["images"].append(
        {
            "id": image_id,
            "file_name": image["file_name"],
            "width": image["width"],
            "height": image["height"]
        }
    )

    # For each annotation in this image
    for ann in image.get("annotations", []):
        # Extract segmentation polygon
        segmentation = ann["segmentation"]

        # Skip if fewer than 3 points (expected to cause errors later)
        if len(segmentation) < 6:
            continue

        # Append annotation
        coco_data["annotations"].append(
            {
                "id": annotation_id,
                "image_id": image_id,
                "category_id": category_map[ann["class"]],
                "segmentation": [segmentation],
                "area": 0,
                "bbox": [
                    min(segmentation[::2]),
                    min(segmentation[1::2]),
                    max(segmentation[::2]) - min(segmentation[::2]),
                    max(segmentation[1::2]) - min(segmentation[1::2])
                ],
                "iscrowd": 0,
                "score": ann.get("confidence_score", 1.0)
            }
        )
        annotation_id += 1

    image_id += 1

# Ensure parent directory exists
output_path.parent.mkdir(parents=True, exist_ok=True)

# Save output
with open(output_path, "w") as f:
    json.dump(coco_data, f, indent=2)

print(f" Saved COCO annotations to: {output_path}")
# Out:
# 📝 Converting Solafune JSON to COCO format...
# ✅ Saved COCO annotations to: /content/treecanopy_data_DL/processed/JSONs/train_annotations_coco.json

# %%
# ============================================================
# COCO TO YOLO CONVERSION
# ============================================================
print("\n Converting COCO format to YOLO format...")

from ultralytics.data.converter import convert_coco

convert_coco(
    labels_dir=DATA_ROOT / 'processed/JSONs',
    save_dir=DATA_ROOT / 'temp/temp_labels',
    use_keypoints=False,
    use_segments=True
)

print("✅ COCO data converted to YOLO format successfully")
# Out:
# 🔄 Converting COCO format to YOLO format...
# Annotations /content/treecanopy_data_DL/processed/JSONs/train_annotations_coco.json: 100% ━━━━━━━━━━━━ 150/150 45.4it/s 3.3s
# COCO data converted successfully.
# Results saved to /content/treecanopy_data_DL/temp/temp_labels3
# ✅ COCO data converted to YOLO format successfully

# %%
# ============================================================
# ORGANIZE IMAGES
# ============================================================
print("\n Organizing images...")

# Adjust these paths based on your Kaggle dataset structure
train_images_source = DATASET_PATH / 'train_images'  # Adjust if needed
eval_images_source = DATASET_PATH / 'evaluation_images'  # Adjust if needed

# Copy training images to temp location
temp_images_dir = DATA_ROOT / 'temp/temp_images'
temp_images_dir.mkdir(parents=True, exist_ok=True)

if train_images_source.exists():
    for img in train_images_source.glob('*'):
        if img.suffix.lower() in {'.jpg', '.jpeg', '.png', '.tif', '.tiff'}:
            shutil.copy(img, temp_images_dir / img.name)
    print(f" Copied training images to: {temp_images_dir}")

# Copy evaluation/prediction images
predict_dir = DATA_ROOT / 'processed/images/predict'
predict_dir.mkdir(parents=True, exist_ok=True)

if eval_images_source.exists():
    for img in eval_images_source.glob('*'):
        if img.suffix.lower() in {'.jpg', '.jpeg', '.png', '.tif', '.tiff'}:
            shutil.copy(img, predict_dir / img.name)
    print(f" Copied prediction images to: {predict_dir}")
# Out:
# 📁 Organizing images...
# ✅ Copied training images to: /content/treecanopy_data_DL/temp/temp_images
# ✅ Copied prediction images to: /content/treecanopy_data_DL/processed/images/predict

# %%
# ============================================================
# DATA SPLIT: Train / Validation (80:20)
# ============================================================
print("\n Splitting data into train/val sets...")

# Paths
IMG_DIR = DATA_ROOT / "temp/temp_images"
LBL_DIR = DATA_ROOT / "temp/temp_labels/labels/train_annotations_coco"
OUT_DIR = DATA_ROOT / "processed"

# Configurations
splits = {"train": 0.80, "val": 0.20}
SEED = 0

# Collect all images
images = list(IMG_DIR.glob("*.jpg")) + list(IMG_DIR.glob("*.png")) + list(IMG_DIR.glob("*.tif"))

# Shuffle by seed for reproducibility
random.seed(SEED)
random.shuffle(images)
print(f'Data split by seed: {SEED}')

# Split indices
n = len(images)
train_end = int(splits["train"] * n)

datasets = {
    "train": images[:train_end],
    "val": images[train_end:]
}

# Copy files into YOLO structure
for split, files in datasets.items():
    (OUT_DIR / "images" / split).mkdir(parents=True, exist_ok=True)
    (OUT_DIR / "labels" / split).mkdir(parents=True, exist_ok=True)

    for img in files:
        label = LBL_DIR / (img.stem + ".txt")
        shutil.copy(img, OUT_DIR / "images" / split / img.name)
        if label.exists():
            shutil.copy(label, OUT_DIR / "labels" / split / label.name)
# Out:
# ✂️ Splitting data into train/val sets...
# Data split by seed: 0

# %%
# ============================================================
# VERIFICATION
# ============================================================
print("\nVerifying data split...")

val_image_path = OUT_DIR / "images" / "val"
val_label_path = OUT_DIR / "labels" / "val"
train_image_path = OUT_DIR / "images" / "train"
train_label_path = OUT_DIR / "labels" / "train"
predict_image_path = OUT_DIR / "images" / "predict"

try:
    # Check if any files exist
    if any(val_label_path.glob('*.txt')) and any(val_image_path.glob('*')):
        print('Successful Data Split:\n  Train - 80%\n  Val - 20%\n')

        val_label_count = len(list(val_label_path.glob("*.txt")))
        val_images_count = len(list(val_image_path.glob("*.[tj][ip][fg]*")))  # matches tif, jpg, png
        print(f"Validation files count:\n  Labels: {val_label_count}\n  Images: {val_images_count}")

        train_label_count = len(list(train_label_path.glob("*.txt")))
        train_images_count = len(list(train_image_path.glob("*.[tj][ip][fg]*")))
        print(f"Training files count:\n  Labels: {train_label_count}\n  Images: {train_images_count}")

        predict_image_count = len(list(predict_image_path.glob("*.[tj][ip][fg]*")))
        print(f"Prediction file count:\n  Images: {predict_image_count}")

        print(f"\n Dataset ready at: {DATA_ROOT}")
    else:
        raise FileNotFoundError(f'No files found in validation directories')

except Exception as e:
    print(f' Data Split Failed - {e}')
# Out:
# 📊 Verifying data split...
# ✅ Successful Data Split:
#   Train - 80%
#   Val - 20%
#
# Validation files count:
#   Labels: 30
#   Images: 30
# Training files count:
#   Labels: 120
#   Images: 120
# Prediction file count:
#   Images: 150
#
# 🎯 Dataset ready at: /content/treecanopy_data_DL

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# **Train Model**

# %%
#@title dataset config
# ============================================================
# STEP 2: CREATE DATASET CONFIG
# ============================================================
print("\n" + "=" * 60)
print("STEP 2: Creating Dataset Configuration")
print("=" * 60)

# DATA_ROOT = Path('/content/treecanopy_data_DL')  # Main data directory


# Create data.yaml for YOLO training
data_yaml_path = DATA_ROOT / 'processed' / 'data.yaml'
data_yaml_content = {
    'path': str(DATA_ROOT / 'processed'),
    'train': 'images/train',
    'val': 'images/val',
    'names': {
        0: 'individual_tree',
        1: 'group_of_trees'
    }
}

import yaml
with open(data_yaml_path, 'w') as f:
    yaml.dump(data_yaml_content, f, default_flow_style=False)

print(f" Created dataset config: {data_yaml_path}\n")
# Out:
# ============================================================
# STEP 2: Creating Dataset Configuration
# ============================================================
# ✅ Created dataset config: /content/treecanopy_data_DL/processed/data.yaml

# %%
#@title Training
import torch
from ultralytics import YOLO
from datetime import datetime

# ============================================================
# STEP 3: TRAIN MODEL
# ============================================================
print("=" * 60)
print("STEP 3: Training YOLO Model")
print("=" * 60)

# Check GPU availability
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f"\n  Training device: {device}")
if device == 'cuda':
    print(f"   GPU: {torch.cuda.get_device_name(0)}")
    print(f"   Memory: {torch.cuda.get_device_properties(0).total_memory / 1e9:.2f} GB")

# Initialize model
model = YOLO('yolo11m-seg.pt')  # You can change to yolo11m-seg.pt, yolo11l-seg.pt, etc.

# Training parameters (customize as needed)
training_args = {
    'data': str(data_yaml_path),
    'epochs':150,              # Adjust as needed
    'imgsz': 640,               # Image size
    'batch': 3,                 # Batch size (adjust based on GPU memory)
    'device': device,
    'project': str(DATA_ROOT / 'runs' / 'segment'),
    'name': f'train_yolo11m_{datetime.now():%Y%m%d_%H%M}',
    'optimizer': 'AdamW',
    'lr0': 0.001,
    'patience': 20,
    'save': True,
    'plots': True,
    'cache': False,             # Set to True if you have enough RAM
    'workers': 2,
    'verbose': True,
    'augment': True # Enabled augmentation
}

print(f"\n Starting training with parameters:")
for key, value in training_args.items():
    print(f"   {key}: {value}")

# Train the model
results = model.train(**training_args)

print(f"\n Training complete!")
print(f" Results saved to: {training_args['project']}/{training_args['name']}")

# Save best model path for prediction
best_model_path = DATA_ROOT / 'runs' / 'segment' / training_args['name'] / 'weights' / 'best.pt'
print(f" Best model: {best_model_path}\n")
# Out:
# ============================================================
# STEP 3: Training YOLO Model
# ============================================================
#
# 🖥️  Training device: cuda
#    GPU: Tesla T4
#    Memory: 15.83 GB
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11m-seg.pt to 'yolo11m-seg.pt': 100% ━━━━━━━━━━━━ 43.3MB 67.6MB/s 0.6s
#
# 🚀 Starting training with parameters:
#    data: /content/treecanopy_data_DL/processed/data.yaml
#    epochs: 150
#    imgsz: 640
#    batch: 3
#    device: cuda
#    project: /content/treecanopy_data_DL/runs/segment
#    name: train_yolo11m_20251205_0459
#    optimizer: AdamW
#    lr0: 0.001
#    patience: 20
#    save: True
#    plots: True
#    cache: False
#    workers: 2
#    verbose: True
#    augment: True
# Ultralytics 8.3.235 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=True, auto_augment=randaugment, batch=3, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/treecanopy_data_DL/processed/data.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=150, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.001, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11m-seg.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=train_yolo11m_20251205_0459, nbs=64, nms=False, opset=None, optimize=False, optimizer=AdamW, overlap_mask=True, patience=20, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/content/treecanopy_data_DL/runs/segment, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/content/treecanopy_data_DL/runs/segment/train_yolo11m_20251205_0459, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=segment, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=2, workspace=None
# Overriding model.yaml nc=80 with nc=2
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1856  ultralytics.nn.modules.conv.Conv             [3, 64, 3, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   2                  -1  1    111872  ultralytics.nn.modules.block.C3k2            [128, 256, 1, True, 0.25]
#   3                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   4                  -1  1    444928  ultralytics.nn.modules.block.C3k2            [256, 512, 1, True, 0.25]
#   5                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   6                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   7                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1   1642496  ultralytics.nn.modules.block.C3k2            [1024, 512, 1, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    542720  ultralytics.nn.modules.block.C3k2            [1024, 256, 1, True]
#  17                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  20                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1642496  ultralytics.nn.modules.block.C3k2            [1024, 512, 1, True]
#  23        [16, 19, 22]  1   3718774  ultralytics.nn.modules.head.Segment          [2, 32, 256, [256, 512, 512]]
# YOLO11m-seg summary: 253 layers, 22,360,758 parameters, 22,360,742 gradients, 113.5 GFLOPs
#
# Transferred 705/711 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 4368.7±1365.6 MB/s, size: 3072.3 KB)
# train: Scanning /content/treecanopy_data_DL/processed/labels/train.cache... 120 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 120/120 201.1Kit/s 0.0s
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1891.2±2135.4 MB/s, size: 3072.3 KB)
# val: Scanning /content/treecanopy_data_DL/processed/labels/val.cache... 30 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 30/30 25.5Kit/s 0.0s
# Plotting labels to /content/treecanopy_data_DL/runs/segment/train_yolo11m_20251205_0459/labels.jpg...
# optimizer: AdamW(lr=0.001, momentum=0.937) with parameter groups 115 weight(decay=0.0), 126 weight(decay=0.0004921875), 125 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /content/treecanopy_data_DL/runs/segment/train_yolo11m_20251205_0459
# Starting training for 150 epochs...
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       1/150      5.15G      2.719      4.593      2.726      1.681        634        640: 100% ━━━━━━━━━━━━ 40/40 1.4s/it 57.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 2.9s/it 14.3s
#                    all         30       6645      0.145       0.15      0.095     0.0486      0.102     0.0906     0.0606      0.021
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       2/150      7.12G      2.203      3.811      1.682      1.366        950        640: 100% ━━━━━━━━━━━━ 40/40 1.1s/it 42.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.4it/s 3.7s
#                    all         30       6645       0.13      0.133     0.0994     0.0457     0.0291     0.0302     0.0147    0.00361
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       3/150      7.65G       2.11      3.619      1.655      1.324       1692        640: 100% ━━━━━━━━━━━━ 40/40 1.0it/s 40.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.6it/s 3.1s
#                    all
# Ultralytics 8.3.235 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11m-seg summary (fused): 138 layers, 22,336,854 parameters, 0 gradients, 112.9 GFLOPs
# WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 20% ━━────────── 1/5 1.2s/it 0.4s<5.0sWARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 40% ━━━━╸─────── 2/5 1.2s/it 1.4s<3.5sWARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 60% ━━━━━━━───── 3/5 1.3s/it 3.1s<2.6sWARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 80% ━━━━━━━━━╸── 4/5 1.4s/it 5.0s<1.4sWARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.4s/it 7.1s
#                    all         30       6645      0.512      0.338      0.366      0.195      0.483      0.322      0.344      0.164
#        individual_tree         30       5902      0.659      0.355      0.448      0.247      0.594      0.319      0.402      0.199
#         group_of_trees         27        743      0.365       0.32      0.283      0.144      0.372      0.326      0.287      0.128
# Speed: 1.3ms preprocess, 43.5ms inference, 0.0ms loss, 21.9ms postprocess per image
# Results saved to /content/treecanopy_data_DL/runs/segment/train_yolo11m_20251205_0459
#
# ✅ Training complete!
# 📁 Results saved to: /content/treecanopy_data_DL/runs/segment/train_yolo11m_20251205_0459
# 🏆 Best model: /content/treecanopy_data_DL/runs/segment/train_yolo11m_20251205_0459/weights/best.pt

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# **Predcitions**

# %%
#@title predcit
import json
from pathlib import Path
from PIL import Image
from ultralytics import YOLO

# ============================================================
# STEP 5: GENERATE SOLAFUNE FORMAT PREDICTIONS
# ============================================================
print("=" * 60)
print("STEP 5: Generating Solafune Format Predictions")
print("=" * 60)

# Paths - automatically find the most recent training run
runs_dir = DATA_ROOT / 'runs' / 'segment'
training_runs = sorted(runs_dir.glob('train_*'), key=lambda x: x.stat().st_mtime, reverse=True)

if not training_runs:
    raise FileNotFoundError(f"No training runs found in {runs_dir}")

latest_run = training_runs[0]
best_model_path = latest_run / 'weights' / 'best.pt'

if not best_model_path.exists():
    raise FileNotFoundError(f"Best model not found at {best_model_path}")

print(f" Using training run: {latest_run.name}")

predict_dir = DATA_ROOT / 'processed' / 'images' / 'predict'
output_json = DATA_ROOT / 'submission.json' # <--- CHANGE THIS LINE to change the name of the ouptut json

# Load original annotations to get metadata (cm_resolution, scene_type)
original_annotations_path = DATASET_PATH / 'train_annotations.json'
with open(original_annotations_path) as f:
    original_data = json.load(f)

# Create lookup for metadata by filename
metadata_lookup = {}
for img in original_data.get('images', []):
    metadata_lookup[img['file_name']] = {
        'cm_resolution': img.get('cm_resolution'),
        'scene_type': img.get('scene_type')
    }

# Load trained model
print(f"\n Loading model from: {best_model_path}")
model = YOLO(str(best_model_path))

# Run predictions (NO save_txt!)
print(f" Running predictions on: {predict_dir}\n")
results = model.predict(
    source=str(predict_dir),
    imgsz=700,                  # Reduced image size to save GPU memory
    conf=0.25,                  # Confidence threshold
    iou=0.75,                    # IoU threshold for NMS
    save=False,                 # Don't save visualizations (optional)
    save_txt=False,             # ← NO YOLO .txt files
    verbose=True,
    half=True                   # Use half precision to save GPU memory
)

# Class mapping (YOLO uses 0-indexed, we need class names)
class_names = {
    0: 'individual_tree',
    1: 'group_of_trees'
}

# Build Solafune format JSON
solafune_data = {"images": []}

for result in results:
    # Get image info
    img_path = Path(result.path)
    img_name = img_path.name

    # Open image to get dimensions
    with Image.open(img_path) as img:
        width, height = img.size

    # Get metadata from original annotations (if available)
    meta = metadata_lookup.get(img_name, {})

    image_entry = {
        "file_name": img_name,
        "width": width,
        "height": height,
        "cm_resolution": meta.get('cm_resolution', 10),  # Default to 10 if not found
        "scene_type": meta.get('scene_type', 'unknown'),
        "annotations": []
    }

    # Process detections
    if result.masks is not None:
        masks = result.masks.xy  # Get polygon coordinates
        boxes = result.boxes

        for i, mask_coords in enumerate(masks):
            # Get class and confidence
            class_id = int(boxes.cls[i].item())
            confidence = float(boxes.conf[i].item())
            class_name = class_names.get(class_id, 'unknown')

            # Flatten polygon coordinates to single list [x1,y1,x2,y2,...]
            segmentation = []
            for point in mask_coords:
                segmentation.append(float(point[0]))  # x
                segmentation.append(float(point[1]))  # y

            # Skip if polygon has fewer than 3 points (6 coordinates)
            if len(segmentation) < 6:
                continue

            annotation = {
                "class": class_name,
                "confidence_score": round(confidence, 5),
                "segmentation": segmentation
            }

            image_entry["annotations"].append(annotation)

    solafune_data["images"].append(image_entry)
    print(f" Processed: {img_name} - {len(image_entry['annotations'])} detections")

# Save to JSON
with open(output_json, 'w') as f:
    json.dump(solafune_data, f, indent=2)

print(f"\n Solafune format predictions saved to: {output_json}")
print(f" Total images: {len(solafune_data['images'])}")
print(f" Total detections: {sum(len(img['annotations']) for img in solafune_data['images'])}")
# Out:
# ============================================================
# STEP 5: Generating Solafune Format Predictions
# ============================================================
# 📂 Using training run: train_yolo11m_20251205_0459
#
# 🔍 Loading model from: /content/treecanopy_data_DL/runs/segment/train_yolo11m_20251205_0459/weights/best.pt
# 🚀 Running predictions on: /content/treecanopy_data_DL/processed/images/predict
#
#
# WARNING ⚠️ imgsz=[700] must be multiple of max stride 32, updating to [704]
# image 1/150 /content/treecanopy_data_DL/processed/images/predict/10cm_evaluation_1.tif: 704x704 31 individual_trees, 24.4ms
# image 2/150 /content/treecanopy_data_DL/processed/images/predict/10cm_evaluation_10.tif: 704x704 30 individual_trees, 8 group_of_treess, 24.4ms
# image 3/150 /content/treecanopy_data_DL/processed/images/predict/10cm_evaluation_11.tif: 704x704 21 individual_trees, 6 group_of_treess, 24.4ms
# image 4/150 /content/treecanopy_data_DL/processed/images/predict/10cm_evaluation_12.tif: 704x704 35 individual_trees, 14 group_of_treess, 24.4ms
# image 5/150 /content/treecanopy_data_DL/processed/images/predict/10cm_evaluation_13.tif: 704x704 124 individual_trees, 18.6ms
# image 6/150 /content/treecanopy_data_DL/processed/images/predict/10cm_evaluation_14.tif: 704x704 53 individual_trees, 1 group_of_trees, 17.5ms
# image 7/150 /content/treecanopy_data_DL/processed/images/predict/10cm_evaluation_15.tif: 704x704 61 individual_trees, 1 group_of_trees, 17.5ms
# image 8/150 /content/treecanopy_data_DL/processed/images/predict/10cm_evaluation_16.tif: 704x704 81 individual_trees, 3 group_of_treess, 15.7ms
# image 9/150 /content/treecanopy_data_DL/processed/images/predict/10cm_evaluation_17.tif: 704x704 39 individual_trees, 8 group_of_treess, 15.6ms
# image 10/150 /content/treecanopy_data_DL/processed/images/predict/10cm_evaluation_18.tif: 704x704 86 individual_trees, 15.3ms
# image 11/150 /content/treecanopy_data_DL/processed/images/predict/10cm_evaluation_19.tif: 704x704 127 individual_trees, 15.2ms
# image 12/150 /content/treecanopy_data_DL/processed/images/predict/10cm_evaluation_2.tif: 704x704 60 individual_trees, 1 group_of_trees, 14.7ms
# image 13/150 /content/treecanopy_data_DL/processed/images/predict/10cm_evaluation_20.tif: 704x704 120 individual_trees, 14.4ms
# image 14/150 /content/treecanopy_data_DL/processed/images/predict/10cm_evaluation_21.tif: 704x704 112 individual_trees, 3 group_of_treess, 14.5ms
# image 15/150 /content/treecanopy_data_DL/processed/images/predict/10cm_evaluation_22.tif: 704x704 113 individual_trees, 1 group_of_trees, 14.5ms
# image 16/150 /content/treecanopy_data_DL/processed/images/predict/10cm_evaluation_23.tif: 704x704 40 individual_trees, 1 group_of_trees, 14.4ms
# image 17/150 /content/treecanopy_data_DL/processed/images/predict/10cm_evaluation_24.tif: 704x704 117 individual_trees, 14.1ms
# image 18/150 /content/treecanopy_data_DL/processed/images/predict/10cm_evaluation_25.tif: 704x704 103 individual_trees, 1 group_of_trees, 14.0ms
# image 19/150 /content/treecanopy_data_DL/processed/images/predict/10cm_evaluation_26.tif: 704x704 26 individual_trees, 2 group_of_treess, 13.6ms
# image 20/150 /content/treecanopy_data_DL/processed/images/predict/10cm_evaluation_27.tif: 704x704 299 individual_trees, 1 group_of_trees, 13.8ms
# image 21/150 /content/treecanopy_data_DL/processed/images/predict/10cm_evaluation_28.tif: 704x704 103 individual_trees, 1 group_of_trees, 17.2ms
# image 22/150 /content/treecanopy_data_DL/processed/images/predict/10cm_evaluation_29.tif: 704x704 71 individual_trees, 3 group_of_treess, 13.4ms
# image 23/150 /content/treecanopy_data_DL/processed/images/predict/10cm_evaluation_3.tif: 704x704 8 individual_trees, 1 group_of_trees, 21.4ms
# image 24/150 /content/treecanopy_data_DL/processed/images/predict/10cm_evaluation_30.tif: 704x704 160 individual_trees, 13.4ms
# image 25/150 /content/treecanopy_data_DL/processed/images/predict/10cm_evaluation_31.tif: 704x704 120 individual_trees, 2 group_of_treess, 15.5ms
# image 26/150 /content/treecanopy_data_DL/processed/images/predict/10cm_evaluation_32.tif: 704x704 228 individual_trees, 2 group_of_treess, 13.2ms
# image 27/150 /content/treecanopy_data_DL/processed/images/predict/10cm_evaluation_33.tif: 704x704 76 individual_trees, 13.2ms
# image 28/150 /content/treecanopy_data_DL/processed/images/predict/10cm_evaluation_34.tif: 704x704 167 individual_trees, 13.7ms
# image 29/150 /content/treecanopy_data_DL/processed/images/predict/10cm_evaluation_35.tif: 704x704 30 individual_trees, 13.3ms
# image 30/150 /content/treecanopy_data_DL/processed/images/predict/10cm_evaluation_36.tif: 704x704 84 individual_trees, 14.0ms
# image 31/150 /content/treecanopy_data_DL/processed/images/predict/10cm_evaluation_37.tif: 704x704 87 individual_trees, 13.3ms
# image 32/150 /content/treecanopy_data_DL/processed/images/predict/10cm_evaluation_38.tif: 704x704 300 individual_trees, 13.4ms
# image 33/150 /content/treecanopy_data_DL/processed/images/predict/10cm_evaluation_4.tif: 704x704 42 individual_trees, 6 group_of_treess, 26.2ms
# image 34/150 /content/treecanopy_data_DL/processed/images/predict/10cm_evaluation_5.tif: 704x704 8 individual_trees, 7 group_of_treess, 27.6ms
# image 35/150 /content/treecanopy_data_DL/processed/images/predict/10cm_evaluation_6.tif: 704x704 10 individual_trees, 3 group_of_treess, 20.1ms
# image 36/150 /content/treecanopy_data_DL/processed/images/predict/10cm_evaluation_7.tif: 704x704 300 individual_trees, 20.1ms
# image 37/150 /content/treecanopy_data_DL/processed/images/predict/10cm_evaluation_8.tif: 704x704 8 individual_trees, 4 group_of_treess, 16.4ms
# image 38/150 /content/treecanopy_data_DL/processed/images/predict/10cm_evaluation_9.tif: 704x704 15 individual_trees, 4 group_of_treess, 15.9ms
# image 39/150 /content/treecanopy_data_DL/processed/images/predict/20cm_evaluation_39.tif: 704x704 104 individual_trees, 28 group_of_treess, 16.9ms
# image 40/150 /content/treecanopy_data_DL/processed/images/predict/20cm_evaluation_40.tif: 704x704 128 individual_trees, 11 group_of_treess, 16.6ms
# image 41/150 /content/treecanopy_data_DL/processed/images/predict/20cm_evaluation_41.tif: 704x704 121 individual_trees, 12 group_of_treess, 16.8ms
# image 42/150 /content/treecanopy_data_DL/processed/images/predict/20cm_evaluation_42.tif: 704x704 62 individual_trees, 15.3ms
# image 43/150 /content/treecanopy_data_DL/processed/images/predict/20cm_evaluation_43.tif: 704x704 183 individual_trees, 24 group_of_treess, 18.1ms
# image 44/150 /content/treecanopy_data_DL/processed/images/predict/20cm_evaluation_44.tif: 704x704 108 individual_trees, 1 group_of_trees, 15.3ms
# image 45/150 /content/treecanopy_data_DL/processed/images/predict/20cm_evaluation_45.tif: 704x704 97 individual_trees, 3 group_of_treess, 22.2ms
# image 46/150 /content/treecanopy_data_DL/processed/images/predict/20cm_evaluation_46.tif: 704x704 72 individual_trees, 1 group_of_trees, 16.7ms
# image 47/150 /content/treecanopy_data_DL/processed/images/predict/20cm_evaluation_47.tif: 704x704 98 individual_trees, 2 group_of_treess, 16.8ms
# image 48/150 /content/treecanopy_data_DL/processed/images/predict/20cm_evaluation_48.tif: 704x704 88 individual_trees, 1 group_of_trees, 24.3ms
# image 49/150 /content/treecanopy_data_DL/processed/images/predict/20cm_evaluation_49.tif: 704x704 108 individual_trees, 27 group_of_treess, 17.3ms
# image 50/150 /content/treecanopy_data_DL/processed/images/predict/20cm_evaluation_50.tif: 704x704 19 individual_trees, 25.5ms
# image 51/150 /content/treecanopy_data_DL/processed/images/predict/20cm_evaluation_51.tif: 704x704 24 individual_trees, 1 group_of_trees, 20.9ms
# image 52/150 /content/treecanopy_data_DL/processed/images/predict/20cm_evaluation_52.tif: 704x704 175 individual_trees, 22 group_of_treess, 21.1ms
# image 53/150 /content/treecanopy_data_DL/processed/images/predict/20cm_evaluation_53.tif: 704x704 45 individual_trees, 20.0ms
# image 54/150 /content/treecanopy_data_DL/processed/images/predict/20cm_evaluation_54.tif: 704x704 65 individual_trees, 16.0ms
# image 55/150 /content/treecanopy_data_DL/processed/images/predict/20cm_evaluation_55.tif: 704x704 79 individual_trees, 3 group_of_treess, 15.7ms
# image 56/150 /content/treecanopy_data_DL/processed/images/predict/20cm_evaluation_56.tif: 704x704 143 individual_trees, 18 group_of_treess, 15.7ms
# image 57/150 /content/treecanopy_data_DL/processed/images/predict/20cm_evaluation_57.tif: 704x704 77 individual_trees, 14.7ms
# image 58/150 /content/treecanopy_data_DL/processed/images/predict/20cm_evaluation_58.tif: 704x704 79 individual_trees, 14.5ms
# image 59/150 /content/treecanopy_data_DL/processed/images/predict/20cm_evaluation_59.tif: 704x704 100 individual_trees, 14.6ms
# image 60/150 /content/treecanopy_data_DL/processed/images/predict/20cm_evaluation_60.tif: 704x704 71 individual_trees, 1 group_of_trees, 14.5ms
# image 61/150 /content/treecanopy_data_DL/processed/images/predict/20cm_evaluation_61.tif: 704x704 38 individual_trees, 1 group_of_trees, 17.2ms
# image 62/150 /content/treecanopy_data_DL/processed/images/predict/20cm_evaluation_62.tif: 704x704 92 individual_trees, 14.5ms
# image 63/150 /content/treecanopy_data_DL/processed/images/predict/20cm_evaluation_63.tif: 704x704 129 individual_trees, 16 group_of_treess, 13.3ms
# image 64/150 /content/treecanopy_data_DL/processed/images/predict/20cm_evaluation_64.tif: 704x704 24 individual_trees, 2 group_of_treess, 13.7ms
# image 65/150 /content/treecanopy_data_DL/processed/images/predict/20cm_evaluation_65.tif: 704x704 106 individual_trees, 14.0ms
# image 66/150 /content/treecanopy_data_DL/processed/images/predict/20cm_evaluation_66.tif: 704x704 52 individual_trees, 1 group_of_trees, 13.4ms
# image 67/150 /content/treecanopy_data_DL/processed/images/predict/20cm_evaluation_67.tif: 704x704 111 individual_trees, 8 group_of_treess, 13.3ms
# image 68/150 /content/treecanopy_data_DL/processed/images/predict/20cm_evaluation_68.tif: 704x704 81 individual_trees, 14.0ms
# image 69/150 /content/treecanopy_data_DL/processed/images/predict/20cm_evaluation_69.tif: 704x704 92 individual_trees, 13.3ms
# image 70/150 /content/treecanopy_data_DL/processed/images/predict/20cm_evaluation_70.tif: 704x704 134 individual_trees, 7 group_of_treess, 17.6ms
# image 71/150 /content/treecanopy_data_DL/processed/images/predict/20cm_evaluation_71.tif: 704x704 68 individual_trees, 13.3ms
# image 72/150 /content/treecanopy_data_DL/processed/images/predict/20cm_evaluation_72.tif: 704x704 160 individual_trees, 10 group_of_treess, 13.3ms
# image 73/150 /content/treecanopy_data_DL/processed/images/predict/20cm_evaluation_73.tif: 704x704 191 individual_trees, 7 group_of_treess, 14.1ms
# image 74/150 /content/treecanopy_data_DL/processed/images/predict/20cm_evaluation_74.tif: 704x704 45 individual_trees, 1 group_of_trees, 13.3ms
# image 75/150 /content/treecanopy_data_DL/processed/images/predict/20cm_evaluation_75.tif: 704x704 22 individual_trees, 2 group_of_treess, 13.6ms
# image 76/150 /content/treecanopy_data_DL/processed/images/predict/40cm_evaluation_100.tif: 704x704 141 individual_trees, 8 group_of_treess, 13.3ms
# image 77/150 /content/treecanopy_data_DL/processed/images/predict/40cm_evaluation_76.tif: 704x704 29 individual_trees, 4 group_of_treess, 13.5ms
# image 78/150 /content/treecanopy_data_DL/processed/images/predict/40cm_evaluation_77.tif: 704x704 48 individual_trees, 25 group_of_treess, 13.2ms
# image 79/150 /content/treecanopy_data_DL/processed/images/predict/40cm_evaluation_78.tif: 704x704 79 individual_trees, 24 group_of_treess, 13.5ms
# image 80/150 /content/treecanopy_data_DL/processed/images/predict/40cm_evaluation_79.tif: 704x704 233 individual_trees, 11 group_of_treess, 15.9ms
# image 81/150 /content/treecanopy_data_DL/processed/images/predict/40cm_evaluation_80.tif: 704x704 91 individual_trees, 36 group_of_treess, 13.6ms
# image 82/150 /content/treecanopy_data_DL/processed/images/predict/40cm_evaluation_81.tif: 704x704 70 individual_trees, 20 group_of_treess, 13.4ms
# image 83/150 /content/treecanopy_data_DL/processed/images/predict/40cm_evaluation_82.tif: 704x704 26 individual_trees, 7 group_of_treess, 14.2ms
# image 84/150 /content/treecanopy_data_DL/processed/images/predict/40cm_evaluation_83.tif: 704x704 143 individual_trees, 6 group_of_treess, 13.9ms
# image 85/150 /content/treecanopy_data_DL/processed/images/predict/40cm_evaluation_84.tif: 704x704 37 individual_trees, 13 group_of_treess, 17.6ms
# image 128/150 /content/treecanopy_data_DL/processed/images/predict/80cm_evaluation_128.tif: 704x704 131 individual_trees, 9 group_of_treess, 14.6ms
# image 129/150 /content/treecanopy_data_DL/processed/images/predict/80cm_evaluation_129.tif: 704x704 195 individual_trees, 15 group_of_treess, 14.8ms
# image 130/150 /content/treecanopy_data_DL/processed/images/predict/80cm_evaluation_130.tif: 704x704 154 individual_trees, 8 group_of_treess, 21.9ms
# image 131/150 /content/treecanopy_data_DL/processed/images/predict/80cm_evaluation_131.tif: 704x704 141 individual_trees, 18 group_of_treess, 14.2ms
# image 132/150 /content/treecanopy_data_DL/processed/images/predict/80cm_evaluation_132.tif: 704x704 231 individual_trees, 69 group_of_treess, 14.6ms
# image 133/150 /content/treecanopy_data_DL/processed/images/predict/80cm_evaluation_133.tif: 704x704 193 individual_trees, 15 group_of_treess, 14.5ms
# image 134/150 /content/treecanopy_data_DL/processed/images/predict/80cm_evaluation_134.tif: 704x704 162 individual_trees, 129 group_of_treess, 15.7ms
# image 135/150 /content/treecanopy_data_DL/processed/images/predict/80cm_evaluation_135.tif: 704x704 87 individual_trees, 19 group_of_treess, 14.7ms
# image 136/150 /content/treecanopy_data_DL/processed/images/predict/80cm_evaluation_136.tif: 704x704 113 individual_trees, 38 group_of_treess, 14.4ms
# image 137/150 /content/treecanopy_data_DL/processed/images/predict/80cm_evaluation_137.tif: 704x704 61 individual_trees, 27 group_of_treess, 14.4ms
# image 138/150 /content/treecanopy_data_DL/processed/images/predict/80cm_evaluation_138.tif: 704x704 70 individual_trees, 27 group_of_treess, 13.7ms
# image 139/150 /content/treecanopy_data_DL/processed/images/predict/80cm_evaluation_139.tif: 704x704 171 individual_trees, 24 group_of_treess, 13.4ms
# image 140/150 /content/treecanopy_data_DL/processed/images/predict/80cm_evaluation_140.tif: 704x704 170 individual_trees, 14 group_of_treess, 13.5ms
# image 141/150 /content/treecanopy_data_DL/processed/images/predict/80cm_evaluation_141.tif: 704x704 150 individual_trees, 28 group_of_treess, 21.8ms
# image 142/150 /content/treecanopy_data_DL/processed/images/predict/80cm_evaluation_142.tif: 704x704 142 individual_trees, 19 group_of_treess, 15.0ms
# image 143/150 /content/treecanopy_data_DL/processed/images/predict/80cm_evaluation_143.tif: 704x704 233 individual_trees, 66 group_of_treess, 13.4ms
# image 144/150 /content/treecanopy_data_DL/processed/images/predict/80cm_evaluation_144.tif: 704x704 240 individual_trees, 56 group_of_treess, 13.7ms
# image 145/150 /content/treecanopy_data_DL/processed/images/predict/80cm_evaluation_145.tif: 704x704 262 individual_trees, 17 group_of_treess, 13.8ms
# image 146/150 /content/treecanopy_data_DL/processed/images/predict/80cm_evaluation_146.tif: 704x704 224 individual_trees, 62 group_of_treess, 13.6ms
# image 147/150 /content/treecanopy_data_DL/processed/images/predict/80cm_evaluation_147.tif: 704x704 243 individual_trees, 57 group_of_treess, 22.6ms
# image 148/150 /content/treecanopy_data_DL/processed/images/predict/80cm_evaluation_148.tif: 704x704 201 individual_trees, 66 group_of_treess, 22.7ms
# image 149/150 /content/treecanopy_data_DL/processed/images/predict/80cm_evaluation_149.tif: 704x704 279 individual_trees, 13 group_of_treess, 16.8ms
# image 150/150 /content/treecanopy_data_DL/processed/images/predict/80cm_evaluation_150.tif: 704x704 207 individual_trees, 93 group_of_treess, 16.3ms
# Speed: 3.7ms preprocess, 15.7ms inference, 76.0ms postprocess per image at shape (1, 3, 704, 704)
# ✅ Processed: 10cm_evaluation_1.tif - 31 detections
# ✅ Processed: 10cm_evaluation_10.tif - 38 detections
# ✅ Processed: 10cm_evaluation_11.tif - 27 detections
# ✅ Processed: 10cm_evaluation_12.tif - 49 detections
# ✅ Processed: 10cm_evaluation_13.tif - 124 detections
# ✅ Processed: 10cm_evaluation_14.tif - 54 detections
# ✅ Processed: 10cm_evaluation_15.tif - 62 detections
# ✅ Processed: 10cm_evaluation_16.tif - 84 detections
# ✅ Processed: 10cm_evaluation_17.tif - 47 detections
# ✅ Processed: 10cm_evaluation_18.tif - 86 detections
# ✅ Processed: 10cm_evaluation_19.tif - 127 detections
# ✅ Processed: 10cm_evaluation_2.tif - 61 detections
# ✅ Processed: 10cm_evaluation_20.tif - 120 detections
# ✅ Processed: 10cm_evaluation_21.tif - 115 detections
# ✅ Processed: 10cm_evaluation_22.tif - 114 detections
# ✅ Processed: 10cm_evaluation_23.tif - 41 detections
# ✅ Processed: 10cm_evaluation_24.tif - 117 detections
# ✅ Processed: 10cm_evaluation_25.tif - 104 detections
# ✅ Processed: 10cm_evaluation_26.tif - 28 detections
# ✅ Processed: 10cm_evaluation_27.tif - 300 detections
# ✅ Processed: 10cm_evaluation_28.tif - 104 detections
# ✅ Processed: 10cm_evaluation_29.tif - 74 detections
# ✅ Processed: 10cm_evaluation_3.tif - 9 detections
# ✅ Processed: 10cm_evaluation_30.tif - 160 detections
# ✅ Processed: 10cm_evaluation_31.tif - 122 detections
# ✅ Processed: 10cm_evaluation_32.tif - 230 detections
# ✅ Processed: 10cm_evaluation_33.tif - 76 detections
# ✅ Processed: 10cm_evaluation_34.tif - 167 detections
# ✅ Processed: 10cm_evaluation_35.tif - 30 detections
# ✅ Processed: 10cm_evaluation_36.tif - 84 detections
# ✅ Processed: 10cm_evaluation_37.tif - 87 detections
# ✅ Processed: 10cm_evaluation_38.tif - 300 detections
# ✅ Processed: 10cm_evaluation_4.tif - 48 detections
# ✅ Processed: 10cm_evaluation_5.tif - 15 detections
# ✅ Processed: 10cm_evaluation_6.tif - 13 detections
# ✅ Processed: 10cm_evaluation_7.tif - 300 detections
# ✅ Processed: 10cm_evaluation_8.tif - 12 detections
# ✅ Processed: 10cm_evaluation_9.tif - 19 detections
# ✅ Processed: 20cm_evaluation_39.tif - 132 detections
# ✅ Processed: 20cm_evaluation_40.tif - 139 detections
# ✅ Processed: 20cm_evaluation_41.tif - 133 detections
# ✅ Processed: 20cm_evaluation_42.tif - 62 detections
# ✅ Processed: 20cm_evaluation_43.tif - 207 detections
# ✅ Processed: 20cm_evaluation_44.tif - 109 detections
# ✅ Processed: 20cm_evaluation_45.tif - 100 detections
# ✅ Processed: 20cm_evaluation_46.tif - 73 detections
# ✅ Processed: 20cm_evaluation_47.tif - 100 detections
# ✅ Processed: 20cm_evaluation_48.tif - 89 detections
# ✅ Processed: 20cm_evaluation_49.tif - 135 detections
# ✅ Processed: 20cm_evaluation_50.tif - 19 detections
# ✅ Processed: 20cm_evaluation_51.tif - 25 detections
# ✅ Processed: 20cm_evaluation_52.tif - 197 detections
# ✅ Processed: 20cm_evaluation_53.tif - 45 detections
# ✅ Processed: 20cm_evaluation_54.tif - 65 detections
# ✅ Processed: 20cm_evaluation_55.tif - 82 detections
# ✅ Processed: 20cm_evaluation_56.tif - 161 detections
# ✅ Processed: 20cm_evaluation_57.tif - 77 detections
# ✅ Processed: 20cm_evaluation_58.tif - 79 detections
# ✅ Processed: 20cm_evaluation_59.tif - 100 detections
# ✅ Processed: 20cm_evaluation_60.tif - 72 detections
# ✅ Processed: 20cm_evaluation_61.tif - 39 detections
# ✅ Processed: 20cm_evaluation_62.tif - 92 detections
# ✅ Processed: 20cm_evaluation_63.tif - 145 detections
# ✅ Processed: 20cm_evaluation_64.tif - 26 detections
# ✅ Processed: 20cm_evaluation_65.tif - 106 detections
# ✅ Processed: 20cm_evaluation_66.tif - 52 detections
# ✅ Processed: 20cm_evaluation_67.tif - 119 detections
# ✅ Processed: 20cm_evaluation_68.tif - 81 detections
# ✅ Processed: 20cm_evaluation_69.tif - 92 detections
# ✅ Processed: 20cm_evaluation_70.tif - 141 detections
# ✅ Processed: 20cm_evaluation_71.tif - 68 detections
# ✅ Processed: 20cm_evaluation_72.tif - 170 detections
# ✅ Processed: 20cm_evaluation_73.tif - 198 detections
# ✅ Processed: 20cm_evaluation_74.tif - 46 detections
# ✅ Processed: 20cm_evaluation_75.tif - 24 detections
# ✅ Processed: 40cm_evaluation_100.tif - 149 detections
# ✅ Processed: 40cm_evaluation_76.tif - 33 detections
# ✅ Processed: 40cm_evaluation_77.tif - 73 detections
# ✅ Processed: 40cm_evaluation_78.tif - 103 detections
# ✅ Processed: 40cm_evaluation_79.tif - 244 detections
# ✅ Processed: 40cm_evaluation_80.tif - 127 detections
# ✅ Processed: 40cm_evaluation_81.tif - 90 detections
# ✅ Processed: 40cm_evaluation_82.tif - 33 detections
# ✅ Processed: 40cm_evaluation_83.tif - 149 detections
# ✅ Processed: 40cm_evaluation_84.tif - 50 detections
# ✅ Processed: 40cm_evaluation_85.tif - 33 detections
# ✅ Processed: 40cm_evaluation_86.tif - 132 detections
# ✅ Processed: 40cm_evaluation_87.tif - 118 detections
# ✅ Processed: 40cm_evaluation_88.tif - 232 detections
# ✅ Processed: 40cm_evaluation_89.tif - 224 detections
# ✅ Processed: 40cm_evaluation_90.tif - 247 detections
# ✅ Processed: 40cm_evaluation_91.tif - 186 detections
# ✅ Processed: 40cm_evaluation_92.tif - 236 detections
# ✅ Processed: 40cm_evaluation_93.tif - 203 detections
# ✅ Processed: 40cm_evaluation_94.tif - 172 detections
# ✅ Processed: 40cm_evaluation_95.tif - 99 detections
# ✅ Processed: 40cm_evaluation_96.tif - 92 detections
# ✅ Processed: 40cm_evaluation_97.tif - 43 detections
# ✅ Processed: 40cm_evaluation_98.tif - 146 detections
# ✅ Processed: 40cm_evaluation_99.tif - 243 detections
# ✅ Processed: 60cm_evaluation_101.tif - 96 detections
# ✅ Processed: 60cm_evaluation_102.tif - 298 detections
# ✅ Processed: 60cm_evaluation_103.tif - 296 detections
# ✅ Processed: 60cm_evaluation_104.tif - 292 detections
# ✅ Processed: 60cm_evaluation_105.tif - 296 detections
# ✅ Processed: 60cm_evaluation_106.tif - 290 detections
# ✅ Processed: 60cm_evaluation_107.tif - 292 detections
# ✅ Processed: 60cm_evaluation_108.tif - 151 detections
# ✅ Processed: 60cm_evaluation_109.tif - 299 detections
# ✅ Processed: 60cm_evaluation_110.tif - 289 detections
# ✅ Processed: 60cm_evaluation_111.tif - 291 detections
# ✅ Processed: 60cm_evaluation_112.tif - 298 detections
# ✅ Processed: 60cm_evaluation_113.tif - 296 detections
# ✅ Processed: 60cm_evaluation_114.tif - 299 detections
# ✅ Processed: 60cm_evaluation_115.tif - 36 detections
# ✅ Processed: 60cm_evaluation_116.tif - 66 detections
# ✅ Processed: 60cm_evaluation_117.tif - 300 detections
# ✅ Processed: 60cm_evaluation_118.tif - 290 detections
# ✅ Processed: 60cm_evaluation_119.tif - 298 detections
# ✅ Processed: 60cm_evaluation_120.tif - 300 detections
# ✅ Processed: 60cm_evaluation_121.tif - 275 detections
# ✅ Processed: 60cm_evaluation_122.tif - 297 detections
# ✅ Processed: 60cm_evaluation_123.tif - 300 detections
# ✅ Processed: 60cm_evaluation_124.tif - 299 detections
# ✅ Processed: 60cm_evaluation_125.tif - 294 detections
# ✅ Processed: 80cm_evaluation_126.tif - 212 detections
# ✅ Processed: 80cm_evaluation_127.tif - 143 detections
# ✅ Processed: 80cm_evaluation_128.tif - 140 detections
# ✅ Processed: 80cm_evaluation_129.tif - 210 detections
# ✅ Processed: 80cm_evaluation_130.tif - 162 detections
# ✅ Processed: 80cm_evaluation_131.tif - 159 detections
# ✅ Processed: 80cm_evaluation_132.tif - 300 detections
# ✅ Processed: 80cm_evaluation_133.tif - 208 detections
# ✅ Processed: 80cm_evaluation_134.tif - 291 detections
# ✅ Processed: 80cm_evaluation_135.tif - 106 detections
# ✅ Processed: 80cm_evaluation_136.tif - 151 detections
# ✅ Processed: 80cm_evaluation_137.tif - 88 detections
# ✅ Processed: 80cm_evaluation_138.tif - 97 detections
# ✅ Processed: 80cm_evaluation_139.tif - 195 detections
# ✅ Processed: 80cm_evaluation_140.tif - 184 detections
# ✅ Processed: 80cm_evaluation_141.tif - 178 detections
# ✅ Processed: 80cm_evaluation_142.tif - 161 detections
# ✅ Processed: 80cm_evaluation_143.tif - 299 detections
# ✅ Processed: 80cm_evaluation_144.tif - 296 detections
# ✅ Processed: 80cm_evaluation_145.tif - 279 detections
# ✅ Processed: 80cm_evaluation_146.tif - 286 detections
# ✅ Processed: 80cm_evaluation_147.tif - 300 detections
# ✅ Processed: 80cm_evaluation_148.tif - 267 detections
# ✅ Processed: 80cm_evaluation_149.tif - 292 detections
# ✅ Processed: 80cm_evaluation_150.tif - 300 detections
#
# 🎉 Solafune format predictions saved to: /content/treecanopy_data_DL/submission.json
# 📊 Total images: 150
# 📊 Total detections: 22478

# %%
from google.colab import files

# Assuming output_json points to the submission.json file
# output_json is already defined in the notebook state as: /content/treecanopy_data_DL/submission.json

files.download(str(output_json))

# %%
# ============================================================
# OPTIONAL: Validate JSON structure
# ============================================================
print("\n" + "=" * 60)
print("Validating JSON Structure")
print("=" * 60)

try:
    # Check required fields
    assert "images" in solafune_data, "Missing 'images' key"

    for i, img in enumerate(solafune_data["images"]):
        assert "file_name" in img, f"Image {i}: Missing 'file_name'"
        assert "width" in img, f"Image {i}: Missing 'width'"
        assert "height" in img, f"Image {i}: Missing 'height'"
        assert "annotations" in img, f"Image {i}: Missing 'annotations'"

        for j, ann in enumerate(img["annotations"]):
            assert "class" in ann, f"Image {i}, Annotation {j}: Missing 'class'"
            assert "confidence_score" in ann, f"Image {i}, Annotation {j}: Missing 'confidence_score'"
            assert "segmentation" in ann, f"Image {i}, Annotation {j}: Missing 'segmentation'"
            assert len(ann["segmentation"]) >= 6, f"Image {i}, Annotation {j}: Polygon too short"

    print(" JSON structure is valid!")
    print(" Ready for Solafune submission!")

except AssertionError as e:
    print(f" Validation failed: {e}")

print("\n" + "=" * 60)
print("COMPLETE PIPELINE FINISHED! 🎊")
print("=" * 60)
print(f"\n Download your submission file:")
print(f"   {output_json}")
# Out:
# ============================================================
# Validating JSON Structure
# ============================================================
# ✅ JSON structure is valid!
# ✅ Ready for Solafune submission!
#
# ============================================================
# COMPLETE PIPELINE FINISHED! 🎊
# ============================================================
#
# 📥 Download your submission file:
#    /content/treecanopy_data_DL/submission.json

# %%
import torch

# Check current CUDA memory usage (optional, for verification)
if torch.cuda.is_available():
    print(f"CUDA Memory before clearing: {torch.cuda.memory_allocated() / (1024**2):.2f} MB")

    # Empty the CUDA cache
    torch.cuda.empty_cache()

    print(f"CUDA Memory after clearing: {torch.cuda.memory_allocated() / (1024**2):.2f} MB")
else:
    print("CUDA is not available.")
# Out:
# CUDA Memory before clearing: 9214.55 MB
# CUDA Memory after clearing: 9214.55 MB

# %% [markdown]
# Keep in mind that `empty_cache()` only clears _unused_ cached memory. If you have large tensors or models still in memory, it won't free up that space until those objects are no longer referenced and are garbage collected. If you continue to face out-of-memory issues, consider reducing batch sizes, model size, or image dimensions, as we did in the previous step.

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# **Visualization**

# %%
#@title Visualization
import cv2
import json
import numpy as np
import random
from pathlib import Path
import matplotlib.pyplot as plt
from matplotlib.patches import Polygon

def visualize_yolo_data(dataset_type=0, num_images=5, data_root=None):
    """
    Visualize YOLO training/validation data with ground truth annotations.

    Parameters:
    -----------
    dataset_type : int
        0 for train data (with ground truth labels)
        1 for validation/prediction data (with model predictions)
    num_images : int
        Number of random images to display
    data_root : Path or str
        Root directory of the dataset (e.g., DATA_ROOT)
    """

    if data_root is None:
        data_root = Path('/content/treecanopy_data_DL')
    else:
        data_root = Path(data_root)

    # Set paths based on dataset type
    if dataset_type == 0:
        # Training data
        split_name = 'Training'
        img_dir = data_root / 'processed' / 'images' / 'train'
        label_dir = data_root / 'processed' / 'labels' / 'train'
        use_txt_labels = True
    else:
        # Validation/Prediction data
        split_name = 'Validation/Prediction'
        img_dir = data_root / 'processed' / 'images' / 'predict'
        prediction_json = data_root / 'submission.json'
        use_txt_labels = False

    # Check if directories exist
    if not img_dir.exists():
        print(f"❌ Image directory not found: {img_dir}")
        return

    if dataset_type == 0 and not label_dir.exists():
        print(f"❌ Label directory not found: {label_dir}")
        return

    if dataset_type == 1 and not prediction_json.exists():
        print(f"❌ Prediction JSON not found: {prediction_json}")
        return

    print(f"📁 Accessing image directory: {img_dir}")

    # Get all image files
    image_files = list(img_dir.glob('*.tif')) + list(img_dir.glob('*.jpg')) + list(img_dir.glob('*.png'))

    if len(image_files) == 0:
        print(f"❌ No images found in {img_dir}")
        return

    # Load predictions if using validation data
    predictions_dict = {}
    if dataset_type == 1:
        with open(prediction_json, 'r') as f:
            predictions_data = json.load(f)

        # Create lookup dictionary: filename -> annotations
        for img_data in predictions_data.get('images', []):
            predictions_dict[img_data['file_name']] = img_data.get('annotations', [])

        print(f"📊 Loaded predictions for {len(predictions_dict)} images")

    # Randomly sample images
    num_images = min(num_images, len(image_files))
    selected_images = random.sample(image_files, num_images)

    # Class names and colors
    class_names = {'individual_tree': 0, 'group_of_trees': 1}
    colors = {0: 'cyan', 1: 'yellow'}

    # Calculate grid layout
    cols = min(3, num_images)
    rows = (num_images + cols - 1) // cols

    fig, axes = plt.subplots(rows, cols, figsize=(6*cols, 6*rows))
    if num_images == 1:
        axes = [axes]
    else:
        axes = axes.flatten() if rows > 1 else axes

    print(f"\n{'='*60}")
    print(f"Visualizing {num_images} {split_name} Images")
    print(f"{'='*60}\n")

    for idx, img_path in enumerate(selected_images):
        # Read image
        img = cv2.imread(str(img_path))
        if img is None:
            print(f"⚠️  Could not read: {img_path.name}")
            continue

        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        h, w = img.shape[:2]

        # Display image
        ax = axes[idx] if num_images > 1 else axes[0]
        ax.imshow(img)
        ax.axis('off')

        annotation_count = {0: 0, 1: 0}

        if use_txt_labels:
            # Read from .txt file (training data)
            label_path = label_dir / (img_path.stem + '.txt')

            if label_path.exists():
                with open(label_path, 'r') as f:
                    lines = f.readlines()

                for line in lines:
                    parts = line.strip().split()
                    if len(parts) < 5:
                        continue

                    class_id = int(parts[0])
                    coords = [float(x) for x in parts[1:]]

                    # Convert normalized coordinates to pixel coordinates
                    points = []
                    for i in range(0, len(coords), 2):
                        x = coords[i] * w
                        y = coords[i+1] * h
                        points.append([x, y])

                    # Draw polygon
                    poly = Polygon(points,
                                 facecolor=colors[class_id],
                                 edgecolor=colors[class_id],
                                 alpha=0.3,
                                 linewidth=2)
                    ax.add_patch(poly)

                    annotation_count[class_id] += 1
        else:
            # Read from submission.json (validation/prediction data)
            if img_path.name in predictions_dict:
                annotations = predictions_dict[img_path.name]

                for ann in annotations:
                    class_name = ann.get('class', 'unknown')
                    class_id = class_names.get(class_name, 0)
                    segmentation = ann.get('segmentation', [])

                    if len(segmentation) < 6:
                        continue

                    # Convert flat list to points (already in pixel coordinates)
                    points = []
                    for i in range(0, len(segmentation), 2):
                        x = segmentation[i]
                        y = segmentation[i+1]
                        points.append([x, y])

                    # Draw polygon
                    confidence = ann.get('confidence_score', 0.0)
                    alpha = 0.3 + (confidence * 0.3)  # More confident = more opaque

                    poly = Polygon(points,
                                 facecolor=colors[class_id],
                                 edgecolor=colors[class_id],
                                 alpha=alpha,
                                 linewidth=2)
                    ax.add_patch(poly)

                    annotation_count[class_id] += 1

        # Create title with annotation counts
        total = annotation_count[0] + annotation_count[1]
        title = f"{img_path.name}\n"
        title += f"Individual: {annotation_count[0]} | Groups: {annotation_count[1]} | Total: {total}"
        ax.set_title(title, fontsize=10, pad=10)

        print(f"✅ {img_path.name}: {annotation_count[0]} individual trees, {annotation_count[1]} groups")

    # Hide extra subplots if any
    for idx in range(num_images, len(axes)):
        axes[idx].axis('off')

    # Add legend
    from matplotlib.patches import Patch
    legend_elements = [
        Patch(facecolor='cyan', alpha=0.5, label='Individual Tree'),
        Patch(facecolor='yellow', alpha=0.5, label='Group of Trees')
    ]

    if dataset_type == 1:
        fig.suptitle('Note: Opacity indicates confidence (more opaque = higher confidence)',
                    fontsize=10, y=0.99)

    fig.legend(handles=legend_elements, loc='upper center',
              bbox_to_anchor=(0.5, 0.98 if dataset_type == 0 else 0.96), ncol=2, fontsize=12)

    plt.tight_layout()
    plt.subplots_adjust(top=0.95 if dataset_type == 0 else 0.93)
    plt.show()

    print(f"\n{'='*60}")
    print(f"Visualization Complete!")
    print(f"{'='*60}\n")


# ============================================================
# USAGE EXAMPLES
# ============================================================

# Example 1: Visualize 5 training images (with ground truth)
# visualize_yolo_data(dataset_type=0, num_images=5, data_root=DATA_ROOT)

# Example 2: Visualize 3 validation/prediction images (with model predictions)
# visualize_yolo_data(dataset_type=1, num_images=3, data_root=DATA_ROOT)

# Example 3: Compare both
# print("TRAINING DATA:")
# visualize_yolo_data(dataset_type=0, num_images=4, data_root=DATA_ROOT)
# print("\nVALIDATION DATA:")
# visualize_yolo_data(dataset_type=1, num_images=4, data_root=DATA_ROOT)

# %%
f# ============================================================
# USAGE EXAMPLES
# ============================================================

# Example 1: Visualize 5 training images (with ground truth)
# visualize_yolo_data(dataset_type=0, num_images=5, data_root=DATA_ROOT)

# Example 2: Visualize 3 validation/prediction images (with model predictions)
visualize_yolo_data(dataset_type=1, num_images=3, data_root=DATA_ROOT)

# Example 3: Compare both
# print("TRAINING DATA:")
# visualize_yolo_data(dataset_type=0, num_images=4, data_root=DATA_ROOT)
# print("\nVALIDATION DATA:")
# visualize_yolo_data(dataset_type=1, num_images=4, data_root=DATA_ROOT)

# %% [markdown]
# ---
